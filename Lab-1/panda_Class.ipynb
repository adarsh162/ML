# %%
## 1)Draw Scatter Plot between SepalLengthCm and SepalWidthCm for “Iris.csv” file with proper labelling.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("Iris.csv")
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
x=df['SepalLengthCm']
y=df['SepalWidthCm']
plt.scatter(x,y,color="red")
plt.xlabel("SepalLengthCm")
plt.ylabel("SepalWidthCm")
# Out:
# Text(0, 0.5, 'SepalWidthCm')

# %%
##2) Draw Histogram of SepalLengthCm with proper labelling.
plt.hist(x,bins=10)
# Out:
# (array([ 9., 23., 14., 27., 16., 26., 18.,  6.,  5.,  6.]),
#  array([4.3 , 4.66, 5.02, 5.38, 5.74, 6.1 , 6.46, 6.82, 7.18, 7.54, 7.9 ]),
#  <a list of 10 Patch objects>)

# %%
##4) Count total null values for each column in this dataset.
print(df.isnull().sum())
df[["SepalLengthCm"]].iloc[1:6,:]
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64
#    SepalLengthCm
# 1            4.9
# 2            4.7
# 3            4.6
# 4            5.0
# 5            5.4

# %%
##5) i) Print first 5 rows of SepalLengthCm. ii) Print from 5th row and onwards and entire columnof Iris.csv dataset.
df.iloc[5:,:]##5) i) Print first 5 rows of SepalLengthCm. ii) Print from 5th row and onwards and entire columnof Iris.csv dataset.
df.iloc[5:,:]
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 5      6            5.4           3.9            1.7           0.4
# 6      7            4.6           3.4            1.4           0.3
# 7      8            5.0           3.4            1.5           0.2
# 8      9            4.4           2.9            1.4           0.2
# 9     10            4.9           3.1            1.5           0.1
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 5       Iris-setosa
# 6       Iris-setosa
# 7       Iris-setosa
# 8       Iris-setosa
# 9       Iris-setosa
# ..              ...
# ...

# %%
##3) Plot bar chart of Species.
import seaborn as sms
sms.countplot("Species",data=df)
plt.title("bar plot")
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0.5, 1.0, 'bar plot')
